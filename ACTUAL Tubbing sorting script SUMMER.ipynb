# %%
import pandas as pd
import numpy as np

import networkx as nx
from pyvis.network import Network
import itertools

from IPython.display import display, HTML

# %%
#import novice sheet as csv

#remember need to change settings so that anyone with the link can view the sheet
sheet_id = "1YCXmJnYtMeJQZFot6O1AFCMf2QE5GgoyPcpJ3M8Qxaw" #google sheets id
sheet_name = "Novice_Availabilities"
url1 = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}" #create f string of url
df = pd.read_csv(url1)
novice_df = df #make df for later
df
# Out:
#        Name # sessions? Rowing/coxing            crsID  \
# 0      Drew           2        Rowing           am2947
# 1      Jack         NaN        Rowing            jj534
# 2      Anna         2-3        Rowing            af605
# 3     Sarah           2        Rowing  Srt44@cam.ac.uk
# 4      Lara         NaN        Rowing            les54
# 5      Jake         NaN        Rowing           jm2238
# 6      Timo           2        Rowing            tn329
# 7    Justin           2        Rowing            jjl74
# 8      Evie         2-3        Rowing            em801
# 9      Bram           1        Rowing            bur20
# 10   Sophie           2        Rowing            sba31
# 11   Bethan           2        Rowing            Bah37
# 12   Sameer         NaN        Coxing            sa914
# 13    Nikki           2        Rowing            nqs20
# 14    Bella           2        Rowing            iac38
# 15     Kate           3        Rowing            ksp36
# 16  Sólveig           2        Rowing            shh35
# 17    Oscar           2        Rowing            ofc23
# 18    Maria           2        Rowing            mv500
# 19      Ben           2        Rowing            pbc29
# 20      NaN         NaN           NaN              NaN
# 21      NaN         NaN           NaN              NaN
# 22      NaN         NaN           NaN              NaN
# 23      NaN         NaN           NaN              NaN
#
#     Monday 27th 09:00-10:00  Monday 10:00-11:00  Monday 14:00-16:00  \
# 0                     False                True                True
# 1                     False               False               False
# 2                     False               False               False
# 3                     False               False               False
# 4                     False               False               False
# 5                     False               False               False
# 6                     False               False               False
# 7                      True               False               False
# 8                     False               False               False
# 9                      True               False                True
# 10                     True                True               False
# 11                    False               False               False
# 12                    False               False               False
# 13                     True                True                True
# 14                     True                True                True
# 15                     True                True                True
# 16                     True                True                True
# 17                     True                True               False
# 18                     True                True               False
# 19                     True                True                True
# 20                    False               False               False
# 21                    False               False               False
# 22                    False               False               False
# 23                    False               False               False
#
#     Monday 18:00-20:00  Tuesday 28th 09:00-10:00  Tuesday 10:00-11:00  ...  \
# 0                False                     False                False  ...
# 1                False                      True                 True  ...
# 2                False                      True                 True  ...
# 3                False                      True                 True  ...
# 4                False                      True                 True  ...
# 5                 True                     False                False  ...
# 6                 True                     False                False  ...
# 7                False                      True                False  ...
# 8                False                      True                 True  ...
# 9                False                     False                False  ...
# 10               False                      True                False  ...
# 11               False                     False                False  ...
# 12               False                      True                 True  ...
# 13               False                      True                 True  ...
# 14               False                      True                False  ...
# 15               False                      True                 True  ...
# 16               False                      True                 True  ...
# 17               False                      True                 True  ...
# 18               False                      True                 True  ...
# 19               False                     False                False  ...
# 20               False                     False                False  ...
# 21               False                     False                False  ...
# 22               False                     False                False  ...
# 23               False                     False                False  ...
#
#     Friday 09:00-10:00  Friday 10:00-11:00  Friday 14:00-16:00  \
# 0                False                True               False
# 1                 True                True               False
# 2                False               False               False
# 3                False               False               False
# 4                 True                True               False
# 5                 True               False               False
# 6                False               False               False
# 7                False               False               False
# 8                 True                True                True
# 9                False               False               False
# 10                True                True               False
# 11               False               False               False
# 12                True                True               False
# 13                True                True               False
# 14                True                True               False
# 15                True                True               False
# 16                True                True               False
# 17                True                True               False
# 18                True                True               False
# 19               False               False               False
# 20               False               False               False
# 21               False               False               False
# 22               False               False               False
# 23               False               False               False
#
#     Friday 18:00-20:00  Saturday 11:00-14:00  Saturday 14:00-16:00  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                  True
# 3                False                  True                  True
# 4                False                 False                 False
# 5                False                 False                 False
# 6                False                 False                 False
# 7                False                 False                 False
# 8                False                  True                  True
# 9                False                 False                 False
# 10               False                 False                 False
# 11               False                  True                  True
# 12               False                 False                 False
# 13               False                 False                 False
# 14               False                 False                 False
# 15               False                 False                 False
# 16               False                 False                 False
# 17               False                  True                 False
# 18               False                 False                 False
# 19               False                 False                 False
# 20               False                 False                 False
# 21               False                 False                 False
# 22               False                 False                 False
# 23               False                 False                 False
#
#     Saturday 18:00-20:00  Sunday 11:00-14:00  Sunday 14:00-16:00  \
# 0                  False               False               False
# 1                  False               False               False
# 2                   True                True                True
# 3                  False                True                True
# 4                  False               False               False
# 5                  False               False                True
# 6                  False               False               False
# 7                  False               False               False
# 8                  False                True                True
# 9                  False               False                True
# 10                 False               False               False
# 11                 False                True                True
# 12                 False               False               False
# 13                 False               False               False
# 14                 False               False               False
# 15                 False               False               False
# 16                 False                True                True
# 17                 False               False               False
# 18                 False               False               False
# 19                 False               False               False
# 20                 False               False               False
# 21                 False               False               False
# 22                 False               False               False
# 23                 False               False               False
#
#     Sunday 18:00-20:00
# 0                False
# 1                False
# 2                 True
# 3                False
# 4                False
# 5                 True
# 6                False
# 7                False
# 8                False
# 9                 True
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16                True
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
#
# [24 rows x 30 columns]

# %%
df = df.get(df["Rowing/coxing"]=="Rowing")#get only those who want to row
df = df.drop(['crsID',"# sessions?","Rowing/coxing"], axis=1).set_index('Name') #removes unwanted columns (experience, comments), sets index as name
df = df[df.index.notnull()] #drops rows where no data entered

#df = df.get(df["Mens/Womens side?"]=="Womens")
df
# Out:
#          Monday 27th 09:00-10:00  Monday 10:00-11:00  Monday 14:00-16:00  \
# Name
# Drew                       False                True                True
# Jack                       False               False               False
# Anna                       False               False               False
# Sarah                      False               False               False
# Lara                       False               False               False
# Jake                       False               False               False
# Timo                       False               False               False
# Justin                      True               False               False
# Evie                       False               False               False
# Bram                        True               False                True
# Sophie                      True                True               False
# Bethan                     False               False               False
# Nikki                       True                True                True
# Bella                       True                True                True
# Kate                        True                True                True
# Sólveig                     True                True                True
# Oscar                       True                True               False
# Maria                       True                True               False
# Ben                         True                True                True
#
#          Monday 18:00-20:00  Tuesday 28th 09:00-10:00  Tuesday 10:00-11:00  \
# Name
# Drew                  False                     False                False
# Jack                  False                      True                 True
# Anna                  False                      True                 True
# Sarah                 False                      True                 True
# Lara                  False                      True                 True
# Jake                   True                     False                False
# Timo                   True                     False                False
# Justin                False                      True                False
# Evie                  False                      True                 True
# Bram                  False                     False                False
# Sophie                False                      True                False
# Bethan                False                     False                False
# Nikki                 False                      True                 True
# Bella                 False                      True                False
# Kate                  False                      True                 True
# Sólveig               False                      True                 True
# Oscar                 False                      True                 True
# Maria                 False                      True                 True
# Ben                   False                     False                False
#
#          Tuesday 14:00-16:00  Tuesday 18:00-20:00  Wednesday 09:00-10:00  \
# Name
# Drew                    True                False                  False
# Jack                   False                False                  False
# Anna                   False                False                  False
# Sarah                  False                False                  False
# Lara                   False                False                  False
# Jake                   False                False                  False
# Timo                   False                 True                  False
# Justin                 False                False                  False
# Evie                    True                 True                   True
# Bram                   False                False                  False
# Sophie                  True                 True                   True
# Bethan                 False                False                  False
# Nikki                  False                False                   True
# Bella                  False                False                   True
# Kate                    True                False                   True
# Sólveig                 True                False                  False
# Oscar                   True                False                  False
# Maria                  False                False                   True
# Ben                    False                False                  False
#
#          Wednesday 10:00-11:00  ...  Friday 09:00-10:00  Friday 10:00-11:00  \
# Name                            ...
# Drew                      True  ...               False                True
# Jack                      True  ...                True                True
# Anna                     False  ...               False               False
# Sarah                    False  ...               False               False
# Lara                      True  ...                True                True
# Jake                     False  ...                True               False
# Timo                     False  ...               False               False
# Justin                   False  ...               False               False
# Evie                      True  ...                True                True
# Bram                     False  ...               False               False
# Sophie                    True  ...                True                True
# Bethan                   False  ...               False               False
# Nikki                     True  ...                True                True
# Bella                     True  ...                True                True
# Kate                      True  ...                True                True
# Sólveig                  False  ...                True                True
# Oscar                    False  ...                True                True
# Maria                     True  ...                True                True
# Ben                      False  ...               False               False
#
#          Friday 14:00-16:00  Friday 18:00-20:00  Saturday 11:00-14:00  \
# Name
# Drew                  False               False                 False
# Jack                  False               False                 False
# Anna                  False               False                 False
# Sarah                 False               False                  True
# Lara                  False               False                 False
# Jake                  False               False                 False
# Timo                  False               False                 False
# Justin                False               False                 False
# Evie                   True               False                  True
# Bram                  False               False                 False
# Sophie                False               False                 False
# Bethan                False               False                  True
# Nikki                 False               False                 False
# Bella                 False               False                 False
# Kate                  False               False                 False
# Sólveig               False               False                 False
# Oscar                 False               False                  True
# Maria                 False               False                 False
# Ben                   False               False                 False
#
#          Saturday 14:00-16:00  Saturday 18:00-20:00  Sunday 11:00-14:00  \
# Name
# Drew                    False                 False               False
# Jack                    False                 False               False
# Anna                     True                  True                True
# Sarah                    True                 False                True
# Lara                    False                 False               False
# Jake                    False                 False               False
# Timo                    False                 False               False
# Justin                  False                 False               False
# Evie                     True                 False                True
# Bram                    False                 False               False
# Sophie                  False                 False               False
# Bethan                   True                 False                True
# Nikki                   False                 False               False
# Bella                   False                 False               False
# Kate                    False                 False               False
# Sólveig                 False                 False                True
# Oscar                   False                 False               False
# Maria                   False                 False               False
# Ben                     False                 False               False
#
#          Sunday 14:00-16:00  Sunday 18:00-20:00
# Name
# Drew                  False               False
# Jack                  False               False
# Anna                   True                True
# Sarah                  True               False
# Lara                  False               False
# Jake                   True                True
# Timo                  False               False
# Justin                False               False
# Evie                   True               False
# Bram                   True                True
# Sophie                False               False
# Bethan                 True               False
# Nikki                 False               False
# Bella                 False               False
# Kate                  False               False
# Sólveig                True                True
# Oscar                 False               False
# Maria                 False               False
# Ben                   False               False
#
# [19 rows x 26 columns]

# %%
#import coach sheet as csv

sheet_id = "1YCXmJnYtMeJQZFot6O1AFCMf2QE5GgoyPcpJ3M8Qxaw" #google sheets id
sheet_name = "Coach_Availabilities"
url2 = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}" #create f string of url
coach_df = pd.read_csv(url2)

#repeat processing steps, same as for novice_df
coach_df = coach_df.set_index("Name") #set the index as the name column
coach_df = coach_df[coach_df.index.notnull()] #drop rows where no-one has entered data
coach_df = coach_df.drop(columns = ["# sessions?","crsID"])

coach_df
# Out:
#           Monday 27th 09:00-10:00  Monday 10:00-11:00  Monday 14:00-16:00  \
# Name
# Isabella                     True                True               False
#
#           Monday 18:00-20:00  Tuesday 28th 09:00-10:00  Tuesday 10:00-11:00  \
# Name
# Isabella                True                      True                 True
#
#           Tuesday 14:00-16:00  Tuesday 18:00-20:00  Wednesday 09:00-10:00  \
# Name
# Isabella                 True                False                   True
#
#           Wednesday 10:00-11:00  ...  Friday 09:00-10:00  Friday 10:00-11:00  \
# Name                             ...
# Isabella                   True  ...                True                True
#
#           Friday 14:00-16:00  Friday 18:00-20:00  Saturday 11:00-14:00  \
# Name
# Isabella                True               False                 False
#
#           Saturday 14:00-16:00  Saturday 18:00-20:00  Sunday 11:00-14:00  \
# Name
# Isabella                 False                 False               False
#
#           Sunday 14:00-16:00  Sunday 18:00-20:00
# Name
# Isabella               False               False
#
# [1 rows x 26 columns]

# %%
available_coach_times = []

for time in coach_df.columns:
    y = coach_df.get(coach_df[time]==True)  #gets coaches who are available and makes df
    if y.empty == False : #if df is empty, then there are no coaches. we don't want that time then. if there are coaches, tell us time
        available_coach_times.append(time) #append time to list
#print(available_coach_times)

# %%
df = df[available_coach_times] #only work with novices when coaches are available

# %%
slots = []

for time in df.columns:
    X = df[df[time] == True].index  #if rower is available at that time
    Y = list(itertools.combinations(X,2))  #pairwise combinations of names
    Z = [y + ([time],) for y in Y] #add rowers and time to list
    slots += Z
    
slots_df = pd.DataFrame(slots, columns=['Rower 1','Rower 2','Time']) #make list into dataframe
#slots_df

# %%
G = nx.from_pandas_edgelist(slots_df, 'Rower 1', 'Rower 2') #create network
net = Network(notebook=True)
net.from_nx(G)
net.show("possible slots.html") #visualise unmatched network
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="possible slots.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
matchings = nx.algorithms.matching.maximal_matching(G) #maximal matching
matchings_df = pd.DataFrame(matchings, columns=['Rower 1','Rower 2']) #make into dataframe

# %%
G = nx.from_pandas_edgelist(matchings_df, 'Rower 1', 'Rower 2')
net = Network(notebook=True)
net.from_nx(G)
net.show("solution.html") #visualise matched network
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="solution.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
match_times = []

for match in matchings: #iterate over dict of matches
    times = []
    df3 = df.loc[match,:]
    for time in df.columns:
        if df3[time].all():
            times.append(time)
    match_times.append(times)
    
matchings_df['Time'] = match_times
#matchings_df

# %%
#create list of rowers who are free when coaches available
df2 = df.apply(pd.Series.value_counts, axis=1).fillna(0)
df2.columns = ["False","True"]

for i, row in df2.iterrows():
    if df2.loc[i,"True"] == 0:
        df2.drop(i, inplace = True)
all_rowers = df2.index.to_list()
#all_rowers

# %%
list_rower_matched = matchings_df["Rower 1"].to_list()
list_rower_matched += matchings_df["Rower 2"].to_list()

unmatched = [x for x in all_rowers if x not in list_rower_matched] #create list of unmatched rowers
#unmatched

# %%
#give a match to unmatched people

for rower in unmatched:
    findfrancis = slots_df.get(slots_df["Rower 1"]==rower)
    if findfrancis.empty == False:
        ranfindfrancis = findfrancis.sample() #randomly pick pair from those available
        matchings_df = matchings_df.append(ranfindfrancis, ignore_index=True) #append pair and time to matchings_df
    
#matchings_df

# %%
#find coaches for all

matchings_df["Coaches available"] = np.nan #empty column for coaches
for i, row in matchings_df.iterrows():
    coach_time = []
    for j in matchings_df.iloc[i,2]: #for each time
        tempcoach = coach_df.get(coach_df[j]==True) #find coaches available at time
        if tempcoach.empty == False:
            coach_time.append(tempcoach.index) #add coach to list if available
        matchings_df.loc[i,"Coaches available"] = [coach_time] #add list to dataframe

#matchings_df
display(HTML(matchings_df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rower 1</th>
#       <th>Rower 2</th>
#       <th>Time</th>
#       <th>Coaches available</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Drew</td>
#       <td>Evie</td>
#       <td>[Tuesday 14:00-16:00, Wednesday 10:00-11:00, Friday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Jack</td>
#       <td>Anna</td>
#       <td>[Tuesday 28th 09:00-10:00, Tuesday 10:00-11:00, Thursday 09:00-10:00, Thursday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella], [Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Sarah</td>
#       <td>Lara</td>
#       <td>[Tuesday 28th 09:00-10:00, Tuesday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Jake</td>
#       <td>Timo</td>
#       <td>[Monday 18:00-20:00]</td>
#       <td>[[[Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Sophie</td>
#       <td>Nikki</td>
#       <td>[Monday 27th 09:00-10:00, Monday 10:00-11:00, Tuesday 28th 09:00-10:00, Wednesday 09:00-10:00, Wednesday 10:00-11:00, Thursday 09:00-10:00, Friday 09:00-10:00, Friday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Justin</td>
#       <td>Bram</td>
#       <td>[Monday 27th 09:00-10:00]</td>
#       <td>[[[Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Sólveig</td>
#       <td>Oscar</td>
#       <td>[Monday 27th 09:00-10:00, Monday 10:00-11:00, Tuesday 28th 09:00-10:00, Tuesday 10:00-11:00, Tuesday 14:00-16:00, Friday 09:00-10:00, Friday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Maria</td>
#       <td>Ben</td>
#       <td>[Monday 27th 09:00-10:00, Monday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Bella</td>
#       <td>Kate</td>
#       <td>[Monday 27th 09:00-10:00, Monday 10:00-11:00, Tuesday 28th 09:00-10:00, Wednesday 09:00-10:00, Wednesday 10:00-11:00, Thursday 09:00-10:00, Thursday 14:00-16:00, Friday 09:00-10:00, Friday 10:00-11:00]</td>
#       <td>[[[Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella], [Isabella]]]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Bethan</td>
#       <td>Oscar</td>
#       <td>[Thursday 14:00-16:00]</td>
#       <td>[[[Isabella]]]</td>
#     </tr>
#   </tbody>
# </table>

# %%
#process novice sheet
novice_df = novice_df.set_index("Name") #set the index as the name column
novice_df = novice_df[novice_df.index.notnull()] #drop rows where no-one has entered data

Rnovice_df = novice_df
#Rnovice_df = Rnovice_df.get(novice_df["Rowing/coxing"]=="Rowing")#get only rowers
Rnovice_df = Rnovice_df.drop(columns = ["crsID","Rowing/coxing"]) #get rid of the columns we don't need for simplicity
Rnovice_df

#table of available rowers
available_coach_times = []

for time in coach_df.columns:
    y = coach_df.get(coach_df[time]==True)  #gets coaches who are available and makes df
    if y.empty == False : #if df is empty, then there are no coaches. we don't want that time then. if there are coaches, tell us time
        available_coach_times.append(time) #append time to list
#print(available_coach_times)

Rnovice_df1 = novice_df[available_coach_times] #gets novice times when coaches available
#print(Rnovice_df1)

results1 = []
storage = []
index = ["Coaches","Rowers","Number of Rowers"]
overview = pd.DataFrame(index = index, columns = available_coach_times)
#overview

results1 = []
storage = []

for time in overview.columns:
    x1 = Rnovice_df1.get(Rnovice_df1[time]== True) #get rowers available at that time
    list1 = x1.index.tolist() #list of rowers available
    number = len(list1)
    tempcoach = coach_df.get(coach_df[time]==True)
    coach_time = []
    if tempcoach.empty == False:
        coach_time.append(tempcoach.index)
    overview.loc["Coaches",time] = coach_time
    overview.loc["Rowers",time] = list1
    overview.loc["Number of Rowers", time] = number
    if overview.loc["Number of Rowers", time] == 0:
        overview.drop(columns = [time], inplace = True) #drop times where there are no rowers



display(HTML(overview.to_html())) #displaying as html allows to see  all list
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Monday 27th 09:00-10:00</th>
#       <th>Monday 10:00-11:00</th>
#       <th>Monday 18:00-20:00</th>
#       <th>Tuesday 28th 09:00-10:00</th>
#       <th>Tuesday 10:00-11:00</th>
#       <th>Tuesday 14:00-16:00</th>
#       <th>Wednesday 09:00-10:00</th>
#       <th>Wednesday 10:00-11:00</th>
#       <th>Wednesday 14:00-16:00</th>
#       <th>Thursday 09:00-10:00</th>
#       <th>Thursday 10:00-11:00</th>
#       <th>Thursday 14:00-16:00</th>
#       <th>Friday 09:00-10:00</th>
#       <th>Friday 10:00-11:00</th>
#       <th>Friday 14:00-16:00</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Coaches</th>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#       <td>[[Isabella]]</td>
#     </tr>
#     <tr>
#       <th>Rowers</th>
#       <td>[Justin, Bram, Sophie, Nikki, Bella, Kate, Sólveig, Oscar, Maria, Ben]</td>
#       <td>[Drew, Sophie, Nikki, Bella, Kate, Sólveig, Oscar, Maria, Ben]</td>
#       <td>[Jake, Timo]</td>
#       <td>[Jack, Anna, Sarah, Lara, Justin, Evie, Sophie, Sameer, Nikki, Bella, Kate, Sólveig, Oscar, Maria]</td>
#       <td>[Jack, Anna, Sarah, Lara, Evie, Sameer, Nikki, Kate, Sólveig, Oscar, Maria]</td>
#       <td>[Drew, Evie, Sophie, Kate, Sólveig, Oscar]</td>
#       <td>[Evie, Sophie, Sameer, Nikki, Bella, Kate, Maria]</td>
#       <td>[Drew, Jack, Lara, Evie, Sophie, Sameer, Nikki, Bella, Kate, Maria]</td>
#       <td>[Anna, Sarah]</td>
#       <td>[Jack, Anna, Lara, Sophie, Sameer, Nikki, Bella, Kate, Sólveig]</td>
#       <td>[Jack, Anna, Lara, Bethan, Sameer, Nikki, Ben]</td>
#       <td>[Drew, Sarah, Sophie, Bethan, Bella, Kate, Oscar]</td>
#       <td>[Jack, Lara, Jake, Evie, Sophie, Sameer, Nikki, Bella, Kate, Sólveig, Oscar, Maria]</td>
#       <td>[Drew, Jack, Lara, Evie, Sophie, Sameer, Nikki, Bella, Kate, Sólveig, Oscar, Maria]</td>
#       <td>[Evie]</td>
#     </tr>
#     <tr>
#       <th>Number of Rowers</th>
#       <td>10</td>
#       <td>9</td>
#       <td>2</td>
#       <td>14</td>
#       <td>11</td>
#       <td>6</td>
#       <td>7</td>
#       <td>10</td>
#       <td>2</td>
#       <td>9</td>
#       <td>7</td>
#       <td>7</td>
#       <td>12</td>
#       <td>12</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
